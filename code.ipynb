# %% [markdown]
# <a href="https://colab.research.google.com/github/SeanBaek111/stablediffusion/blob/main/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# !pip install --upgrade keras-cv
# Out:
# Tue Nov  1 11:36:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import time
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512)
# Out:
# ...
# 1356917/1356917 [==============================] - 0s 0us/step
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE
# ...
# 198180272/198180272 [==============================] - 13s 0us/step

# %%
def plot_images(images):
  plt.figure(figsize=(20,20))
  for i in range(len(images)):
    ax = plt.subplot(1, len(images), i+1)
    plt.imshow(images[i])
    plt.axis("off")
    plt.tight_layout()

# %%
images = model.text_to_image("photograph of an astronaut riding a horse", batch_size=3)
plot_images(images)
# Out:
# 25/25 [==============================] - 61s 2s/step

# %%
images = model.text_to_image("photograph of a persian cat grooming a white turkish angora", batch_size=3)
plot_images(images)
# Out:
# 25/25 [==============================] - 59s 2s/step
